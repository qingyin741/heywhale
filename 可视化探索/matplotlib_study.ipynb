# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.8.1'

# %%
dir(matplotlib)
# Out:
# ['ExecutableNotFoundError',
#  'MatplotlibDeprecationWarning',
#  'MutableMapping',
#  'Parameter',
#  'Path',
#  'RcParams',
#  '_ExecInfo',
#  '_VersionInfo',
#  '__all__',
#  '__bibtex__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_add_data_doc',
#  '_api',
#  '_c_internal_utils',
#  '_check_versions',
#  '_cm',
#  '_cm_listed',
#  '_color_data',
#  '_deprecated_ignore_map',
#  '_deprecated_map',
#  '_deprecated_remain_as_none',
#  '_docstring',
#  '_ensure_handler',
#  '_enums',
#  '_fontconfig_pattern',
#  '_get_config_or_cache_dir',
#  '_get_executable_info',
#  '_get_ssl_context',
#  '_get_version',
#  '_get_xdg_cache_dir',
#  '_get_xdg_config_dir',
#  '_init_tests',
#  '_label_from_arg',
#  '_log',
#  '_logged_cached',
#  '_open_file_or_url',
#  '_parse_to_version_info',
#  '_path',
#  '_preprocess_data',
#  '_rc_params_in_file',
#  '_replacer',
#  '_val_or_rc',
#  '_version',
#  'atexit',
#  'bezier',
#  'cbook',
#  'cm',
#  'color_sequences',
#  'colormaps',
#  'colors',
#  'contextlib',
#  'cycler',
#  'defaultParams',
#  'ft2font',
#  'functools',
#  'get_backend',
#  'get_cachedir',
#  'get_configdir',
#  'get_data_path',
#  'importlib',
#  'inspect',
#  'interactive',
#  'is_interactive',
#  'locale',
#  'logging',
#  'matplotlib_fname',
#  'namedtuple',
#  'numpy',
#  'os',
#  'parse_version',
#  'path',
#  'pprint',
#  'rc',
#  'rcParams',
#  'rcParamsDefault',
#  'rcParamsOrig',
#  'rc_context',
#  'rc_file',
#  'rc_file_defaults',
#  'rc_params',
#  'rc_params_from_file',
#  'rcdefaults',
#  'rcsetup',
#  're',
#  'sanitize_sequence',
#  'scale',
#  'set_loglevel',
#  'shutil',
#  'subprocess',
#  'sys',
#  'tempfile',
#  'ticker',
#  'transforms',
#  'use',
#  'validate_backend',
#  'warnings']

# %%
import matplotlib.pyplot as plt
#魔法命令，内联显示matplotlib图表
# %matplotlib inline
#确保图表以SVG形式保存
# %config InlineBackend.figure_format='svg'
#解决中文显示乱码问题
plt.rcParams["font.sans-serif"]="SimHei"
#解决负号无法显示的问题
plt.rcParams["axes.unicode_minus"]=False

# %%
import matplotlib.pyplot as plt
# 查看matplotlib的绘图样式
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# 设置绘图样式为ggplot
plt.style.use("ggplot")

# %%
# 设置画布大小
plt.figure(figsize=(9, 6))

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.style as psl
# %matplotlib inline
# %config InlineBackend.figure_format='svg'
plt.rcParams["font.sans-serif"]="SimHei"
plt.rcParams["axes.unicode_minus"]=False

psl.use("ggplot")
#设置画布大小
plt.figure(figsize=(9,6))
plt.plot(np.random.randn(100))

# %% [markdown]
# 坐标轴标题

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as psl
#魔法命令
# %matplotlib inline
#save style =svg
# %config InlineBackend.figure_format='svg'
#slove the problem about chinese word and 
plt.rcParams["font.sans-serif"]='SimHei'
plt.rcParams["axes.unicode_minus"]=False

psl.use('ggplot')
plt.figure(figsize=(9,6))
s=pd.Series(data=np.random.randn(3600),
            index=pd.date_range('20120101',periods=3600),)

cs=s.cumsum()
cs.plot(figsize=(9,6))
plt.xlabel("年份",labelpad=20)
plt.ylabel("网页浏览量",labelpad=20)
# Out:
# Text(0, 0.5, '网页浏览量')

# %% [markdown]
# 图表标题

# %%
import pandas as py
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.style as psl

# %matplotlib inline
# %config InlineBackend.figure_format='svg'
plt.rcParams["font.sans-serif"]='SimHei'
plt.rcParams["axes.unicode_minus"]=False

psl.use('ggplot')
plt.figure(figsize=(9,6))
s=pd.Series(data=np.random.randn(3600),
            index=pd.date_range('20120101',periods=3600),)

cs=s.cumsum()
cs.plot(figsize=(9,6))
plt.title("近十年网页浏览量数据趋势",loc="center")
# Out:
# Text(0.5, 1.0, '近十年网页浏览量数据趋势')

# %% [markdown]
# 图表图例

# %%
import pandas as py
import matplotlib.pyplot as plt
import matplotlib.style as psl
import numpy as np

# %matplotlib inline
# %config InlineBackend.figure_format='svg'
plt.rcParams["font.sans-serif"]="Simhei"
plt.rcParams["axes.unicode_minus"]=False

psl.use('ggplot')
plt.figure(figsize=(9,6))
s=pd.Series(data=np.random.randn(3600),
            index=pd.date_range('20120101',periods=3600),)
cs=s.cumsum()
cs.plot(figsize=(9,6))
plt.legend(loc="upper center",title='浏览量',title_fontsize=10,frameon=False)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# 轴显示设置

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as psl
#魔法方法，内联显示
# %matplotlib inline
# 确保图表以svg格式显示
# %config InlineBackend.figure_format='svg'
psl.use('ggplot')
plt.figure(figsize=(9,6))

#模拟数据
s = pd.Series(data=np.random.randn(3600), 
               index=pd.date_range('20130101',periods=3600),
             )

cs=s.cumsum()
cs.plot(figsize=(9,6))
plt.axis("off")
# Out:
# (15706.0, 19305.0, -167.7045897262683, 39.11293088786973)

# %%
plt.rcParams["font.sans-serif"] = "SimHei"
plt.rcParams["axes.unicode_minus"] = False

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.style as psl

# %matplotlib inline
# %config InlineBackend.figure_format='svg'
psl.use('ggplot')
plt.figure(figsize=(9,6))
s = pd.Series(data=np.random.randn(3600), 
               index=pd.date_range('20130101',periods=3600),
             )

cs=s.cumsum()
cs.plot(figsize=(9,6))
plt.axis('off')
# Out:
# (15706.0, 19305.0, -80.38534777170283, 11.909038602331396)

# %% [markdown]
# df.plot(kind='line', ax=None, subplots=False, sharex=None, sharey=False, layout=None, figsize=None, use_index=True, title=None, grid=None, legend=True, style=None, logx=False, logy=False, loglog=False, xticks=None, yticks=None, xlim=None, ylim=None, rot=None, fontsize=None, colormap=None, table=False, yerr=None, xerr=None, label=None, secondary_y=False, sort_columns=False, \*\*kwds)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as psl

# %matplotlib inline
# %config InlineBackend.figure_format='svg'
psl.use('ggplot')
plt.figure(figsize=(9,6))
plt.rcParams["font.sans-serif"]="SimHei"
plt.rcParams['axes.unicode_minus']=False

df = pd.DataFrame(data=np.random.randint(low=100, high=1000, size=30),
                  index=pd.date_range('20231101', periods=30),
                  columns=['销量'])

df.plot(
    color='red',
    linestyle='--',
    linewidth=2,
    marker='o',
    markersize=5,
    figsize=(9,6)
    
)
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as psl

# %matplotlib inline
# %config InlineBackend.figure_format='svg'
psl.use('ggplot')
plt.figure(figsize=(9,6))
plt.rcParams["font.sans-serif"]="SimHei"
plt.rcParams['axes.unicode_minus']=False
df = pd.DataFrame(data=np.random.randint(low=100, high=1000, size=30),
                  index=pd.date_range('20231101', periods=30),
                  columns=['销量'])
df.plot(figsize=(9,6))
plt.xticks(
    ticks=pd.date_range('20231101',periods=30),
    labels=['{}日'.format(i+1) for i in range(30)],
    rotation=45             #设置x坐标轴刻度
)
plt.yticks(
    ticks=np.arange(100,1100,100),
    labels=['{}单'.format(i*100) for i in range(10)]    #设置y坐标轴刻度
)
# Out:
# ([<matplotlib.axis.YTick at 0x189ed8add30>,
#   <matplotlib.axis.YTick at 0x189ed916c60>,
#   <matplotlib.axis.YTick at 0x189ed916900>,
#   <matplotlib.axis.YTick at 0x189edc34c20>,
#   <matplotlib.axis.YTick at 0x189edc35580>,
#   <matplotlib.axis.YTick at 0x189edc35ee0>,
#   <matplotlib.axis.YTick at 0x189edc36870>,
#   <matplotlib.axis.YTick at 0x189edc371d0>,
#   <matplotlib.axis.YTick at 0x189edc360c0>,
#   <matplotlib.axis.YTick at 0x189edc37800>],
#  [Text(0, 100, '0单'),
#   Text(0, 200, '100单'),
#   Text(0, 300, '200单'),
#   Text(0, 400, '300单'),
#   Text(0, 500, '400单'),
#   Text(0, 600, '500单'),
#   Text(0, 700, '600单'),
#   Text(0, 800, '700单'),
#   Text(0, 900, '800单'),
#   Text(0, 1000, '900单')])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as psl

# %matplotlib inline
# %config InlineBackend.figure_format='svg'
psl.use('ggplot')
plt.figure(figsize=(9,6))
plt.rcParams["font.sans-serif"]="SimHei"
plt.rcParams['axes.unicode_minus']=False


df = pd.DataFrame(data=np.random.randint(low=100, high=1000, size=30),
                  index=pd.date_range('20231101', periods=30),
                  columns=['销量'])

df.plot(figsize=(9, 6))

plt.ylim(0,1200)
# Out:
# (0.0, 1200.0)

# %%
#数据标签
#plt.text()可在指定的坐标位置添加文本，循环遍历每个数据点，并在每个数据点的位置添加一个标签。
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #导入matplotlib包
import matplotlib.style as psl

#魔法命令，用于在笔记本内联显示matplotlib图表
# %matplotlib inline 
#确保图表以SVG格式显示
# %config InlineBackend.figure_format = 'svg' 

psl.use('ggplot')
plt.figure(figsize = (9, 6)) #设置图表画布大小

df=pd.DataFrame(data=np.random.randint(low=100,high=1000,size=30),
                index=pd.date_range('20231101',periods=30),
                columns=['销量'])

df.plot(figsize = (9, 6))


for x, y in zip(pd.date_range('20231101',periods=30),df['销量'].values):
    plt.text(x,y,y,ha='center',va='bottom',fontsize=9)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #导入matplotlib包
import matplotlib.style as psl

#魔法命令，用于在笔记本内联显示matplotlib图表
# %matplotlib inline 
#确保图表以SVG格式显示
# %config InlineBackend.figure_format = 'svg' 

psl.use('ggplot')
plt.figure(figsize = (9, 6)) #设置图表画布大小

df = pd.DataFrame(data=np.random.randint(low=100, high=1000, size=30),
                  index=pd.date_range('20231101', periods=30),
                  columns=['销量'])

df.plot(figsize=(9, 6))
plt.grid(
    color='red',
    which='major',
    linstyle='--',
    alpha=0.3,
    axis='y',
    visible=True,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 19
#      14 df = pd.DataFrame(data=np.random.randint(low=100, high=1000, size=30),
#      15                   index=pd.date_range('20231101', periods=30),
#      16                   columns=['销量'])
#      18 df.plot(figsize=(9, 6))
# ---> 19 plt.grid(
#      20     color='red',
#      21     which='major',
#      22     linstyle='--',
#      23     alpha=0.3,
#      24     axis='y',
#      25     visible=True,
#      26 )
#
# File c:\Users\W10\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3144, in grid(visible, which, axis, **kwargs)
#    3137 @_copy_docstring_and_deprecators(Axes.grid)
#    3138 def grid(
#    3139     visible: bool | None = None,
#    (...)
#    3142     **kwargs,
#    3143 ) -> None:
# -> 3144     gca().grid(visible=visible, which=which, axis=axis, **kwargs)
#
# File c:\Users\W10\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:3198, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3196     self.xaxis.grid(visible, which=which, **kwargs)
#    3197 if axis in ['y', 'both']:
# -> 3198     self.yaxis.grid(visible, which=which, **kwargs)
#
# File c:\Users\W10\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1697, in Axis.grid(self, visible, which, **kwargs)
#    1694 if which in ['major', 'both']:
#    1695     gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1696                         if visible is None else visible)
# -> 1697     self.set_tick_params(which='major', **gridkw)
#    1698 self.stale = True
#
# File c:\Users\W10\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:958, in Axis.set_tick_params(self, which, reset, **kwargs)
#     945 """
#     946 Set appearance parameters for ticks, ticklabels, and gridlines.
#     947
#    (...)
#     955     gridlines.
#     956 """
#     957 _api.check_in_list(['major', 'minor', 'both'], which=which)
# --> 958 kwtrans = self._translate_tick_params(kwargs)
#     960 # the kwargs are stored in self._major/minor_tick_kw so that any
#     961 # future new ticks will automatically get them
#     962 if reset:
#
# File c:\Users\W10\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1102, in Axis._translate_tick_params(kw, reverse)
#    1100 for key in kw_:
#    1101     if key not in allowed_keys:
# -> 1102         raise ValueError(
#    1103             "keyword %s is not recognized; valid keywords are %s"
#    1104             % (key, allowed_keys))
#    1105 kwtrans.update(kw_)
#    1106 return kwtrans
#
# ValueError: keyword grid_linstyle is not recognized; valid keywords are ['size', 'width', 'color', 'tickdir', 'pad', 'labelsize', 'labelcolor', 'labelfontfamily', 'zorder', 'gridOn', 'tick1On', 'tick2On', 'label1On', 'label2On', 'length', 'direction', 'left', 'bottom', 'right', 'top', 'labelleft', 'labelbottom', 'labelright', 'labeltop', 'labelrotation', 'grid_agg_filter', 'grid_alpha', 'grid_animated', 'grid_antialiased', 'grid_clip_box', 'grid_clip_on', 'grid_clip_path', 'grid_color', 'grid_dash_capstyle', 'grid_dash_joinstyle', 'grid_dashes', 'grid_data', 'grid_drawstyle', 'grid_figure', 'grid_fillstyle', 'grid_gapcolor', 'grid_gid', 'grid_in_layout', 'grid_label', 'grid_linestyle', 'grid_linewidth', 'grid_marker', 'grid_markeredgecolor', 'grid_markeredgewidth', 'grid_markerfacecolor', 'grid_markerfacecoloralt', 'grid_markersize', 'grid_markevery', 'grid_mouseover', 'grid_path_effects', 'grid_picker', 'grid_pickradius', 'grid_rasterized', 'grid_sketch_params', 'grid_snap', 'grid_solid_capstyle', 'grid_solid_joinstyle', 'grid_transform', 'grid_url', 'grid_visible', 'grid_xdata', 'grid_ydata', 'grid_zorder', 'grid_aa', 'grid_c', 'grid_ds', 'grid_ls', 'grid_lw', 'grid_mec', 'grid_mew', 'grid_mfc', 'grid_mfcalt', 'grid_ms']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #导入matplotlib包
import matplotlib.style as psl

#魔法命令，用于在笔记本内联显示matplotlib图表
# %matplotlib inline 
#确保图表以SVG格式显示
# %config InlineBackend.figure_format = 'svg' 

psl.use('ggplot')
plt.figure(figsize = (9, 6)) #设置图表画布大小

df = pd.DataFrame(np.random.randn(2000, 4),
                  index=pd.Series(pd.date_range('20230101', periods=2000)),
                  columns=list('ABCD')
                  )
df.cumsum()
df.plot(figsize=(9,6))
plt.legend(loc='best')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #导入matplotlib包
import matplotlib.style as psl

#魔法命令，用于在笔记本内联显示matplotlib图表
# %matplotlib inline 
#确保图表以SVG格式显示
# %config InlineBackend.figure_format = 'svg' 

psl.use('ggplot')
plt.figure(figsize = (9, 6)) #设置图表画布大小

df = pd.DataFrame(np.random.randn(2000, 4),
                  index=pd.Series(pd.date_range('20230101', periods=2000)),
                  columns=list('ABCD')
                  )
df = df.cumsum()
df.plot(figsize=(9, 6), subplots=True,)#共享x轴

plt.legend(loc='best')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as psl

# %matplotlib inline
# %config InlineBackend.figure_format='svg'
psl.use('ggplot')
plt.figure(figsize=(9,6))
plt.rcParams["font.sans-serif"]="SimHei"
plt.rcParams['axes.unicode_minus']=False
df=pd.DataFrame(
    data=np.random.randint(low=100,high=1000,size=30),
    index=pd.date_range('20231101',periods=30),
    columns=['销量']                )

df.plot(
    color='red',
    linestyle='dashdot',
    linewidth=1,
    marker='o',
    markersize=5,
    figsize=(9,6)
)


plt.xlabel('年份',labelpad=20)  #设置x轴距离，labelpad控制标题到图表的距离
plt.ylabel('电商销售量',labelpad=20) #设置y轴距离，labelpad控制标题到图表的距离

plt.title('双十一销售量数据趋势',loc='center')

plt.legend(loc='upper center',title='销量',title_fontsize=10,frameon=False)

plt.xticks(
    pd.date_range('20231101',periods=30),
    ['{}日'.format(i+1) for i in range(30)],
    rotation=45
)

plt.yticks(
    np.arange(100,1100,100),
    ['{}单'.format(i*100) for i in range(10)]
    
)

plt.ylim(0,1100)
plt.grid(visible=True,linstyle='dashed')

for a,b in zip(pd.date_range('20231101',periods=30),df['销量'].values):
    plt.text(a,b,b,ha='center',va='bottom',fontsize=9)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 47
#      40 plt.yticks(
#      41     np.arange(100,1100,100),
#      42     ['{}单'.format(i*100) for i in range(10)]
#      43
#      44 )
#      46 plt.ylim(0,1100)
# ---> 47 plt.grid(visible=True,linstyle='dashed')
#      49 for a,b in zip(pd.date_range('20231101',periods=30),df['销量'].values):
#      50     plt.text(a,b,b,ha='center',va='bottom',fontsize=9)
#
# File c:\Users\W10\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3144, in grid(visible, which, axis, **kwargs)
#    3137 @_copy_docstring_and_deprecators(Axes.grid)
#    3138 def grid(
#    3139     visible: bool | None = None,
#    (...)
#    3142     **kwargs,
#    3143 ) -> None:
# -> 3144     gca().grid(visible=visible, which=which, axis=axis, **kwargs)
#
# File c:\Users\W10\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:3196, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3194 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3195 if axis in ['x', 'both']:
# -> 3196     self.xaxis.grid(visible, which=which, **kwargs)
#    3197 if axis in ['y', 'both']:
#    3198     self.yaxis.grid(visible, which=which, **kwargs)
#
# File c:\Users\W10\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1697, in Axis.grid(self, visible, which, **kwargs)
#    1694 if which in ['major', 'both']:
#    1695     gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1696                         if visible is None else visible)
# -> 1697     self.set_tick_params(which='major', **gridkw)
#    1698 self.stale = True
#
# File c:\Users\W10\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:958, in Axis.set_tick_params(self, which, reset, **kwargs)
#     945 """
#     946 Set appearance parameters for ticks, ticklabels, and gridlines.
#     947
#    (...)
#     955     gridlines.
#     956 """
#     957 _api.check_in_list(['major', 'minor', 'both'], which=which)
# --> 958 kwtrans = self._translate_tick_params(kwargs)
#     960 # the kwargs are stored in self._major/minor_tick_kw so that any
#     961 # future new ticks will automatically get them
#     962 if reset:
#
# File c:\Users\W10\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1102, in Axis._translate_tick_params(kw, reverse)
#    1100 for key in kw_:
#    1101     if key not in allowed_keys:
# -> 1102         raise ValueError(
#    1103             "keyword %s is not recognized; valid keywords are %s"
#    1104             % (key, allowed_keys))
#    1105 kwtrans.update(kw_)
#    1106 return kwtrans
#
# ValueError: keyword grid_linstyle is not recognized; valid keywords are ['size', 'width', 'color', 'tickdir', 'pad', 'labelsize', 'labelcolor', 'labelfontfamily', 'zorder', 'gridOn', 'tick1On', 'tick2On', 'label1On', 'label2On', 'length', 'direction', 'left', 'bottom', 'right', 'top', 'labelleft', 'labelbottom', 'labelright', 'labeltop', 'labelrotation', 'grid_agg_filter', 'grid_alpha', 'grid_animated', 'grid_antialiased', 'grid_clip_box', 'grid_clip_on', 'grid_clip_path', 'grid_color', 'grid_dash_capstyle', 'grid_dash_joinstyle', 'grid_dashes', 'grid_data', 'grid_drawstyle', 'grid_figure', 'grid_fillstyle', 'grid_gapcolor', 'grid_gid', 'grid_in_layout', 'grid_label', 'grid_linestyle', 'grid_linewidth', 'grid_marker', 'grid_markeredgecolor', 'grid_markeredgewidth', 'grid_markerfacecolor', 'grid_markerfacecoloralt', 'grid_markersize', 'grid_markevery', 'grid_mouseover', 'grid_path_effects', 'grid_picker', 'grid_pickradius', 'grid_rasterized', 'grid_sketch_params', 'grid_snap', 'grid_solid_capstyle', 'grid_solid_joinstyle', 'grid_transform', 'grid_url', 'grid_visible', 'grid_xdata', 'grid_ydata', 'grid_zorder', 'grid_aa', 'grid_c', 'grid_ds', 'grid_ls', 'grid_lw', 'grid_mec', 'grid_mew', 'grid_mfc', 'grid_mfcalt', 'grid_ms']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #导入matplotlib包
import matplotlib.style as psl

#魔法命令，用于在笔记本内联显示matplotlib图表
# %matplotlib inline 
#确保图表以SVG格式显示
# %config InlineBackend.figure_format = 'svg' 

psl.use('ggplot')
plt.figure(figsize = (9, 6)) #设置图表画布大小

#导入数据
df=pd.DataFrame(data={'日期': pd.date_range('20231101',periods=30),
                      '销售数': np.random.randint(low=100,high=1000,size=30),
                      '销售额': np.random.randint(low=1000,high=10000,size=30)}
               )
x=df['日期'].astype('str').tolist()
y=df['销售数'].tolist()

plt.plot(x,y,color="red",linestyle= "--",linewidth=1,marker="o",markersize=5)

plt.xlabel("日期",labelpad = 20) #设置X轴距离，labelpad控制标题到图表的距离
plt.ylabel("电商销售数",labelpad = 20) #设置Y轴距离，labelpad控制标题到图表的距离

plt.title('双十一销售量数据趋势', loc = "center")

plt.xticks(x, ['{}日'.format(i+1) for i in range(30)],rotation=45)#设置X坐标轴刻度

plt.grid(visible = True,linestyle='dashed')#设置网格线为虚线,axis='y'可只对Y轴打开网格线

for a,b in zip(x, y):
    plt.text(a,b,b, ha = "center", va = "bottom", fontsize = 9)

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as psl
# %matplotlib inline
# %config InlineBackend.figure_format='svg'
psl.use('ggplot')
plt.figure(figsize=(9,6))
plt.rcParams["font.sans-serif"]="SimHei"
plt.rcParams['axes.unicode_minus']=False

df=pd.DataFrame(data={
    '客户性别':['男','女'],
    '销售数':np.random.randint(low=100,high=5000,size=2)
                      })

x=df['客户性别'].tolist()
y=df['销售数'].tolist()

plt.bar(x,y,width=0.2,align='center',label='销售量')
for a ,b in zip(x,y):
    plt.text(a,b,b,ha='center',va="bottom",fontsize=12)
    
plt.xlabel('客户性别')
plt.ylabel('销售数')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #导入matplotlib包
import matplotlib.style as psl

#魔法命令，用于在笔记本内联显示matplotlib图表
# %matplotlib inline 
#确保图表以SVG格式显示
# %config InlineBackend.figure_format = 'svg' 

psl.use('ggplot')
plt.figure(figsize = (9, 6)) #设置图表画布大小

#导入数据
df=pd.DataFrame(data={'商品品类':['床品件套','厨房电器','汽车配件','浴室用品',
                              '卧室家具','电脑硬件','家装饰品','办公家具'],
                      '销售数': np.random.randint(low=100,high=5000,size=8)}
               )
x=df['商品品类'].tolist()
y=df['销售数'].tolist()

plt.barh(x,width=y,height=0.5,align='center',label='销售数')
plt.title('不同商品品类销售数',loc='center')

for a,b in zip(x,y):
    plt.text(b,a,b,ha='left',va='center',fontsize=12)

plt.xlabel('销售数')
plt.ylabel('商品品类')
plt.legend()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #导入matplotlib包
import matplotlib.style as psl

#魔法命令，用于在笔记本内联显示matplotlib图表
# %matplotlib inline 
#确保图表以SVG格式显示
# %config InlineBackend.figure_format = 'svg' 

psl.use('ggplot')
plt.figure(figsize = (9, 6)) #设置图表画布大小
df=pd.DataFrame(data={'区域':['华东','华北','东北','西北','西南','华南'],
                      '销售数': np.random.randint(low=100,high=5000,size=6)}
               )
x=df['销售数'].tolist()
labels = df['区域'].tolist()

explode=[0.01,0.03,0.05,0,0,0]
plt.pie(x,
        autopct='%.1f%%',
        labels=labels,
        startangle=90,
        explode=explode,
        pctdistance=0.87,
        textprops={'fontsize':12,'color':'k'},
        counterclock=False,)
plt.title('各区域销售数占比')
# Out:
# Text(0.5, 1.0, '各区域销售数占比')

# %%
import pandas as pd  
# 生成日期范围  
date_rng = pd.date_range(start='2023-11-1', end='2023-11-30', freq='D') 

# 创建一个DataFrame  
df = pd.DataFrame(date_rng, columns=['日期'])
df['销量'] = [544, 749, 716, 818, 927, 938,  995, 1161, 997,  1110, 
               1465, 1312, 1400, 1097, 1123,  716, 875,  661,  596, 880,
               969,  709, 993, 1142,  821,  913, 945,  530,  860, 927]
# Out:
# Timestamp('2023-11-11 00:00:00')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9, 6))
plt.plot(df['日期'],df['销量'],marker='o',linestyle='-',color='r')
plt.title('销售趋势图')
#x,y轴标题
plt.xlabel('日期')
plt.ylabel('销售量')
plt.xticks(rotation=45)  #设置x坐标轴刻度
for a,b in zip(df['日期'],df['销量']):
    plt.text(a,b,str(b),ha='center',va='bottom',fontsize=8)
    
plt.grid(True)
plt.show()
