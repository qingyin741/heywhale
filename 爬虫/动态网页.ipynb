# %% [markdown]
# 动态网页处理方法：
# 1. js逆向，直接破解JavaScript代码采集的内容
# 2. 抓包分析，查看截图请求响应信息，伪造请求，实现响应的获取，找到真实数据的动态链接
# 3. 使用python第三方库运行Javascript，直接采集你在浏览器看到的页面，即模拟登录

# %%
import requests
headers = {
    'authority': 'api.qimai.cn',
    'sec-ch-ua': '"Google Chrome";v="93", " Not;A Brand";v="99", "Chromium";v="93"',
    'accept': 'application/json, text/plain, */*',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.63 Safari/537.36',
    'sec-ch-ua-platform': '"Windows"',
    'origin': 'https://www.qimai.cn',
    'sec-fetch-site': 'same-site',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.qimai.cn/',
    'accept-language': 'zh-CN,zh;q=0.9',
    'cookie': 'qm_check=A1sdRUIQChtxen8pI0dAMRcOUFseEHBeQF0JTjVBWCwycRd1QlhAXFEGFUdeSklaHQdKAAkABA1cV1BBWD0TR1JRRAp0BQlFEBQ3TSZKFUdBbwxvBBRFIlQsSUhTFxsQU1FVV1NHXEVYVElWBRsCHAkSSQ%3D%3D; gr_user_id=39ba0c9e-7d2e-4efc-a7f9-4656db894b7d; AUTHKEY=oT3bZIQm3n1vUXS9sjPzP9vc5vSqU2%2FPuBptbIrfpQCNqZ%2FC241%2B0anWPyfKstyhscWSKIk17gjmN6H5M443yx%2ByrCm9wvPE8lOicHkVtJykWTC8M8FR%2Bw%3D%3D; ada35577182650f1_gr_last_sent_cs1=qm16616646146; aso_ucenter=6d65gUMJUI9kCiGJRCs3UfxtAhcK%2B4ju8uZ7anwKugnl56INrFRQ5TYrMspDffQXb%2B0; PHPSESSID=g84cq81ndj0hi4q7v6p82soqtm; USERINFO=U6ChFk7C4bJAQ2MJ88wQUNUdaNAOGIvf%2BPwOmB9nKzv2%2BqX%2F8%2F95EHoatbz1uKNNc3xOM72ACGBf50TtZkHug6cr%2FrSh5zaYOcpT7TJ07%2B67uB9NVm52ObAdAOsNre%2BEpJuubqiNG0zAwbJSIEYcawylGZOSMNR1; ada35577182650f1_gr_session_id=c2601d18-8f22-4549-94b1-d74d2d39f1e2; ada35577182650f1_gr_last_sent_sid_with_cs1=c2601d18-8f22-4549-94b1-d74d2d39f1e2; ada35577182650f1_gr_session_id_sent_vst=c2601d18-8f22-4549-94b1-d74d2d39f1e2; synct=1711384160.318; syncd=-791; tgw_l7_route=d09474674af82c17375cfcdd775c0c28; ada35577182650f1_gr_cs1=qm16616646146'
}
params = (
    ('analysis', 'ew8vECUSKA54dXoXKQtgTCsLIRsaPjRAUG8hCwMLAwkmREcKGBReHl4NAARBZgkTFEcaCxtbVWgKAE4IdkZTV1lOSUgHBQNRXSEaBQ'),
    ('brand', 'all'),
    ('country', 'cn'),
    ('device', 'iphone'),
    ('genre', '36'),
    ('date', '2024-03-26'),
    ('page', '2'),
)
try:
    response=requests.get('https://api.qimai.cn/rank/indexPlus/brand_id/1',headers=headers,params=params)
    if response.status_code==200:
        print('请求成功')
        print(response.json())
except requests.ConnectionError as e:
    print('Error',e.args)
# Out:
# 请求成功
# ...

# %%
response.json()
# Out:
# {'code': 10000,
#  'msg': '成功',
#  'time': '2024年03月26日',
#  'time_format': '',
#  'list': [{'index': 21,
#    'appInfo': {'appId': '333206289',
#     'appName': '支付宝-便捷生活，一点就好',
#     'subtitle': '暂无数据',
#     'icon': 'https://is1-ssl.mzstatic.com/image/thumb/Purple221/v4/85/af/a8/85afa8a3-c1b2-d02e-64c7-25a01336b670/AppIcon2-0-0-1x_U007emarketing-0-7-0-0-85-220.png/180x180bb.png',
#     'publisher': 'Alipay (Hangzhou) Technology Co., Ltd.',
#     'country': 'cn',
#     'file_size': '370793472',
#     'price': '0.00'},
#    'class': {'ranking': '2'},
#    'change': -4,
#    'genre': '生活',
#    'appGenre': '生活',
#    'publisher_id': '333206292',
#    'is_ad': True},
#   {'index': 22,
#    'appInfo': {'appId': '1012871328',
#     'appName': '得物 - 得到运动x潮流x好物',
#     'subtitle': '潮流生活方式平台',
#     'icon': 'https://is1-ssl.mzstatic.com/image/thumb/Purple211/v4/a8/85/4b/a8854b7a-d51b-5101-e5c1-0d9c740f9324/AppIcon-0-0-1x_U007emarketing-0-7-0-0-85-220.png/180x180bb.png',
# ...

# %%
list=response.json()['list']

results=[]

for i in list:
    result={}
    result['APP']=i['appInfo']['appName']
    result['类型']=i['genre']
    result['公司']=i['appInfo']['publisher']
    result['排名']=i['index']
    print(result)
    results.append(result)
# Out:
# {'APP': '支付宝-便捷生活，一点就好', '类型': '生活', '公司': 'Alipay (Hangzhou) Technology Co., Ltd.', '排名': 21}
# {'APP': '得物 - 得到运动x潮流x好物', '类型': '体育', '公司': 'Shanghai Shi Zhuang Information Technology Co.,Ltd.', '排名': 22}
# {'APP': '饿了么-外卖放心点，美食准时达', '类型': '美食佳饮', '公司': 'Shanghai Rajax Information Technology Co., Ltd.', '排名': 23}
# {'APP': '剪映', '类型': '摄影与录像', '公司': '深圳市脸萌科技有限公司', '排名': 24}
# {'APP': '拼多多 - 多多买菜，百亿补贴', '类型': '购物', '公司': '上海寻梦信息技术有限公司', '排名': 25}
# {'APP': '快手', '类型': '摄影与录像', '公司': 'Beijing Kwai Technology Co., Ltd.', '排名': 26}
# {'APP': '淘宝 - 太好逛了吧', '类型': '购物', '公司': '浙江淘宝网络有限公司', '排名': 27}
# {'APP': '汽水音乐 - 抖音音乐版', '类型': '音乐', '公司': 'Beijing Microlive Vision Technology Co., Ltd', '排名': 28}
# {'APP': 'QQ', '类型': '社交', '公司': 'Tencent Technology (Shenzhen) Company Limited', '排名': 29}
# {'APP': '美团-美好生活小帮手', '类型': '生活', '公司': '美团', '排名': 30}
# {'APP': '企业微信', '类型': '商务', '公司': 'Tencent Technology (Shenzhen) Company Limited', '排名': 31}
# ...

# %%
print(len(results))
# Out:
# 20
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
